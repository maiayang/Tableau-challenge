# %%
#import modules
import os
import glob
import pandas as pd

#list all csv files only
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['JC-202306-citibike-tripdata.csv',
#  'JC-202307-citibike-tripdata.csv',
#  'JC-202308-citibike-tripdata.csv',
#  'JC-202311-citibike-tripdata.csv',
#  'JC-202312-citibike-tripdata.csv',
#  'JC-202401-citibike-tripdata.csv',
#  'JC-202402-citibike-tripdata.csv']

# %%
df_concat = pd.concat([pd.read_csv(f) for f in csv_files ], ignore_index=True)
df_concat
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       37BE5FCB1A385CDA   classic_bike  2023-06-27 16:06:27
# 1       9C96B4C6CBBB31AD   classic_bike  2023-06-24 10:46:58
# 2       C91293605D4BEC07  electric_bike  2023-06-04 20:30:13
# 3       2920063442116A46   classic_bike  2023-06-08 19:10:06
# 4       E205FD8C18BA263A   classic_bike  2023-06-23 18:53:51
# ...                  ...            ...                  ...
# 556253  B4251D3376B59FF2  electric_bike  2024-02-25 09:38:44
# 556254  513FF14445FD5A5E  electric_bike  2024-02-26 11:52:05
# 556255  87DBD5B9091DFEC3  electric_bike  2024-02-05 17:05:38
# 556256  8DD48EA418BCA621  electric_bike  2024-02-22 18:42:50
# 556257  9F03340617826524   classic_bike  2024-02-28 08:39:10
#
#                    ended_at     start_station_name start_station_id  \
# 0       2023-06-27 16:10:27                Hilltop            JC019
# 1       2023-06-24 10:55:27  Baldwin at Montgomery            JC020
# ...

# %%
df_concat.to_csv('combined_csv.csv')
